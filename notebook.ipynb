# %%
from tracegraph import draw_dot
from value import Value

# %%
a = Value(1.5)
a.label = "a"
b = Value(-1)
b.label = "b"

c = a * b
c.label = "c"

d = Value(0.5)
d.label = "d"
e = d + c
e.label = "e"

f = e.tanh()
f.label="f"
f.backward()

draw_dot(f)
# Out:
# -0.7615941559557649
